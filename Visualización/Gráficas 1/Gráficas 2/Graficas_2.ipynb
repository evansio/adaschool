# %%
pip install pandas matplotlib

# %%
#carga el archivo data.csv
import pandas as pd
df = pd.read_csv('data.csv')
df.head()
# Out:
#    id      materia  nota aprobado
# 0   1  Matemáticas    80       Sí
# 1   2     Historia    65       No
# 2   3     Ciencias    90       Sí
# 3   4     Lenguaje    75       Sí
# 4   5  Matemáticas    95       Sí

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Crear el DataFrame con los datos proporcionados
Matematicas = df[df['materia'] == 'Matemáticas']['nota']
Historia = df[df['materia'] == 'Historia']['nota']
Ciencias = df[df['materia'] == 'Ciencias']['nota']
Lenguas = df[df['materia'] == 'Lenguaje']['nota']

df = pd.DataFrame(data)

# Gráfico de boxplot para la distribución de notas
plt.figure(figsize=(8, 6))
plt.boxplot([Matematicas, Historia, Ciencias, Lenguas], labels=['Matemáticas', 'Historia', 'Ciencias', 'Lenguaje'])
plt.title('Distribución de Notas')
plt.xlabel('Materia')
plt.show()

# %%
# Gráfico de pie chart para la distribución de aprobados
aprobados_counts = df['aprobado'].value_counts()
labels = aprobados_counts.index
sizes = aprobados_counts.values

plt.figure(figsize=(6, 6))
plt.pie(sizes, labels=['Aprobados', 'No Aprobados'], autopct='%1.1f%%', startangle=90, colors=['blue', 'red'])
plt.title('Distribución de Aprobados')
plt.show()
